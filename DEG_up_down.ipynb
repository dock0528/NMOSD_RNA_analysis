# %%
import numpy as np
import pandas as pd

# %%
def up_down_deg(intersect_degs,external_up,external_down,my_up,my_down):
    # 先把它們各自變成 set
    set_ext_up   = set(external_up['x'])
    set_ext_down = set(external_down['x'])
    set_my_up  = set(my_up['x'])
    set_my_down= set(my_down['x'])

    # 建DataFrame
    df = pd.DataFrame({'DEG':intersect_degs })

    # 第 1 欄：external 是 up 還是 down
    df['external_DEGs'] = df['DEG'].map(
        lambda g: 'up' if g in set_ext_up
                else ('down' if g in set_ext_down else 'NA')
    )

    # 第 2 欄：My DEGs 是 up 還是 down
    df['My_DEGs'] = df['DEG'].map(
        lambda g: 'up' if g in set_my_up
                else ('down' if g in set_my_down else 'NA')
    )

    print(df)

# %%
external_with10_degs =[
  "ENSG00000132704", "ENSG00000163534", "ENSG00000179639",
  "ENSG00000132185", "ENSG00000153064", "ENSG00000164330",
  "ENSG00000082293", "ENSG00000236871", "ENSG00000136573",
  "ENSG00000160932", "ENSG00000137101", "ENSG00000100721",
  "ENSG00000211898", "ENSG00000211899", "ENSG00000247982",
  "ENSG00000177455", "ENSG00000104921", "ENSG00000012124",
  "ENSG00000105369"
]

# %%
external_up=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGS_UP(External dataset).csv")
external_down=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGS_DOWN(External dataset).csv")

# %%
housekeeping10_up=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGS_UP(10Control Genes Batch Effect Correction).csv")
housekeeping10_down=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGS_DOWN(10Control Genes Batch Effect Correction).csv")

# %%
external_up
# Out:
#                   x
# 0   ENSG00000237973
# 1   ENSG00000188290
# 2   ENSG00000187608
# 3   ENSG00000126709
# 4   ENSG00000122420
# ..              ...
# 85  ENSG00000233493
# 86  ENSG00000184979
# 87  ENSG00000100336
# 88  ENSG00000179750
# 89  ENSG00000157601
#
# [90 rows x 1 columns]

# %%
# 先把它們各自變成 set，加速查詢
set_ext_up   = set(external_up['x'])
set_ext_down = set(external_down['x'])
set_ctrl_up  = set(housekeeping10_up['x'])
set_ctrl_down= set(housekeeping10_down['x'])

# 建一張新的 DataFrame
df = pd.DataFrame({'DEG': external_with10_degs})

# 第 1 欄：external 是 up 還是 down
df['external_DEGs'] = df['DEG'].map(
    lambda g: 'up' if g in set_ext_up
              else ('down' if g in set_ext_down else 'NA')
)

# 第 2 欄：10 control DEGs 下是 up 還是 down
df['control_DEGs'] = df['DEG'].map(
    lambda g: 'up' if g in set_ctrl_up
              else ('down' if g in set_ctrl_down else 'NA')
)

print(df)
# Out:
#                 DEG external_DEGs control_DEGs
# 0   ENSG00000132704          down           up
# 1   ENSG00000163534          down           up
# 2   ENSG00000179639          down         down
# 3   ENSG00000132185          down           up
# 4   ENSG00000153064          down           up
# 5   ENSG00000164330          down           up
# 6   ENSG00000082293          down           up
# 7   ENSG00000236871          down         down
# 8   ENSG00000136573          down           up
# 9   ENSG00000160932            up           up
# 10  ENSG00000137101          down           up
# 11  ENSG00000100721          down           up
# 12  ENSG00000211898          down           up
# 13  ENSG00000211899          down           up
# 14  ENSG00000247982          down           up
# 15  ENSG00000177455          down           up
# 16  ENSG00000104921          down           up
# 17  ENSG00000012124          down           up
# 18  ENSG00000105369          down           up

# %%
up_down_deg(external_with10_degs,external_up,external_down,housekeeping10_up,housekeeping10_down)
# Out:
#                 DEG external_DEGs control_DEGs
# 0   ENSG00000132704          down           up
# 1   ENSG00000163534          down           up
# 2   ENSG00000179639          down         down
# 3   ENSG00000132185          down           up
# 4   ENSG00000153064          down           up
# 5   ENSG00000164330          down           up
# 6   ENSG00000082293          down           up
# 7   ENSG00000236871          down         down
# 8   ENSG00000136573          down           up
# 9   ENSG00000160932            up           up
# 10  ENSG00000137101          down           up
# 11  ENSG00000100721          down           up
# 12  ENSG00000211898          down           up
# 13  ENSG00000211899          down           up
# 14  ENSG00000247982          down           up
# 15  ENSG00000177455          down           up
# 16  ENSG00000104921          down           up
# 17  ENSG00000012124          down           up
# 18  ENSG00000105369          down           up

# %%
ori_up=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGS_UP(origin).csv")
ori_down=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGS_DOWN(origin).csv")

# %%
external_with_ori_degs = [
    "ENSG00000187608", "ENSG00000126709", "ENSG00000132185",
    "ENSG00000134326", "ENSG00000153253", "ENSG00000236871",
    "ENSG00000136573", "ENSG00000160932", "ENSG00000137101",
    "ENSG00000196092", "ENSG00000205056", "ENSG00000135114",
    "ENSG00000211899", "ENSG00000167483", "ENSG00000159958"
]

# %%
up_down_deg(external_with_ori_degs,external_up,external_down,ori_up,ori_down)
# Out:
#                 DEG external_DEGs control_DEGs
# 0   ENSG00000187608            up           up
# 1   ENSG00000126709            up           up
# 2   ENSG00000132185          down           up
# 3   ENSG00000134326            up           up
# 4   ENSG00000153253          down         down
# 5   ENSG00000236871          down         down
# 6   ENSG00000136573          down           up
# 7   ENSG00000160932            up           up
# 8   ENSG00000137101          down           up
# 9   ENSG00000196092          down         down
# 10  ENSG00000205056          down         down
# 11  ENSG00000135114            up           up
# 12  ENSG00000211899          down           up
# 13  ENSG00000167483          down         down
# 14  ENSG00000159958          down         down

# %%
external_with_ori_type_IFN_DEGs = [
    "ENSG00000187608", "ENSG00000126709", "ENSG00000132185",
    "ENSG00000134326", "ENSG00000160932", "ENSG00000159958",
    "ENSG00000137101", "ENSG00000135114", "ENSG00000211899",
 
]

# %%
up_down_deg(external_with_ori_type_IFN_DEGs,external_up,external_down,ori_up,ori_down)
# Out:
#                DEG external_DEGs control_DEGs
# 0  ENSG00000187608            up           up
# 1  ENSG00000126709            up           up
# 2  ENSG00000132185          down           up
# 3  ENSG00000134326            up           up
# 4  ENSG00000160932            up           up
# 5  ENSG00000159958          down         down
# 6  ENSG00000137101          down           up
# 7  ENSG00000135114            up           up
# 8  ENSG00000211899          down           up

# %%
external_with_ori_HALLMARK_IFN_DEGs=[
  "ENSG00000187608",
  "ENSG00000134326",
  "ENSG00000160932",
  "ENSG00000135114"]

# %%
up_down_deg(external_with_ori_HALLMARK_IFN_DEGs,external_up,external_down,ori_up,ori_down)
# Out:
#                DEG external_DEGs control_DEGs
# 0  ENSG00000187608            up           up
# 1  ENSG00000134326            up           up
# 2  ENSG00000160932            up           up
# 3  ENSG00000135114            up           up

# %% [markdown]
# ### **Protein Coding Genes**

# %%
external_with_ori_protein_coding_DEGs = [
    "ENSG00000187608", "ENSG00000126709", "ENSG00000117228",
    "ENSG00000132185", "ENSG00000134326", "ENSG00000153253",
    "ENSG00000131016", "ENSG00000136573", "ENSG00000160932",
    "ENSG00000137101", "ENSG00000196092", "ENSG00000135114",
    "ENSG00000167483", "ENSG00000269404", "ENSG00000159958"
]

# %%
external_up_protein_coding=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGS_UP(External dataset)(protein coding genes).csv")
external_down_protein_coding=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGS_DOWN(External dataset)(protein coding genes).csv")

# %%
ori_up_protein_coding=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGS_UP(protein codin genes).csv")
ori_down_protein_coding=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGS_DOWN(protein codin genes).csv")

# %%
up_down_deg(external_with_ori_protein_coding_DEGs,external_up_protein_coding,external_down_protein_coding,ori_up_protein_coding,ori_down_protein_coding)
# Out:
#                 DEG external_DEGs My_DEGs
# 0   ENSG00000187608            up      up
# 1   ENSG00000126709            up      up
# 2   ENSG00000117228            up    down
# 3   ENSG00000132185          down      up
# 4   ENSG00000134326            up      up
# 5   ENSG00000153253          down    down
# 6   ENSG00000131016          down    down
# 7   ENSG00000136573          down      up
# 8   ENSG00000160932            up      up
# 9   ENSG00000137101          down      up
# 10  ENSG00000196092          down    down
# 11  ENSG00000135114            up      up
# 12  ENSG00000167483          down    down
# 13  ENSG00000269404          down    down
# 14  ENSG00000159958          down    down

# %%
external_with_ori_type_IFN_protein_coding_DEGs= [
    "ENSG00000187608",
    "ENSG00000126709",
    "ENSG00000117228",
    "ENSG00000132185",
    "ENSG00000134326",
    "ENSG00000131016",
    "ENSG00000160932",
    "ENSG00000137101",
    "ENSG00000135114",
    "ENSG00000159958"
]

# %%
up_down_deg(external_with_ori_type_IFN_protein_coding_DEGs,external_up_protein_coding,external_down_protein_coding,ori_up_protein_coding,ori_down_protein_coding)
# Out:
#                DEG external_DEGs My_DEGs
# 0  ENSG00000187608            up      up
# 1  ENSG00000126709            up      up
# 2  ENSG00000117228            up    down
# 3  ENSG00000132185          down      up
# 4  ENSG00000134326            up      up
# 5  ENSG00000131016          down    down
# 6  ENSG00000160932            up      up
# 7  ENSG00000137101          down      up
# 8  ENSG00000135114            up      up
# 9  ENSG00000159958          down    down

# %%
external_with_ori_HALLMARK_IFN_protein_coding_DEGs = [
    "ENSG00000187608",
    "ENSG00000134326",
    "ENSG00000160932",
    "ENSG00000135114"
]

# %%
up_down_deg(external_with_ori_HALLMARK_IFN_protein_coding_DEGs,external_up_protein_coding,external_down_protein_coding,ori_up_protein_coding,ori_down_protein_coding)
# Out:
#                DEG external_DEGs My_DEGs
# 0  ENSG00000187608            up      up
# 1  ENSG00000134326            up      up
# 2  ENSG00000160932            up      up
# 3  ENSG00000135114            up      up

# %% [markdown]
# ### **Deseq2 DEGs intersection**

# %%
external_with_ori_degs = [
    "ENSG00000165949", "ENSG00000160932", "ENSG00000159958", "ENSG00000149534", "ENSG00000158715",
    "ENSG00000089127", "ENSG00000179348", "ENSG00000131016", "ENSG00000187608", "ENSG00000167483",
    "ENSG00000134321", "ENSG00000136573", "ENSG00000171766", "ENSG00000135114", "ENSG00000185745",
    "ENSG00000126709", "ENSG00000132530", "ENSG00000211892", "ENSG00000105426", "ENSG00000214711",
    "ENSG00000119922", "ENSG00000187912", "ENSG00000134326", "ENSG00000177455", "ENSG00000132185",
    "ENSG00000134668", "ENSG00000224376", "ENSG00000263417", "ENSG00000123095"
]

# %%
external_up=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGS_UP(external)(Deseq2).csv")
external_down=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGS_DOWN(external)(Deseq2).csv")

# %%
ori_up=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGS_UP(origin)(Deseq2).csv")
ori_down=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGS_DOWN(origin)(Deseq2).csv")

# %%
up_down_deg(external_with_ori_degs,external_up,external_down,ori_up,ori_down)
# Out:
#                 DEG external_DEGs My_DEGs
# 0   ENSG00000165949            up      up
# 1   ENSG00000160932            up      up
# 2   ENSG00000159958          down    down
# 3   ENSG00000149534          down    down
# 4   ENSG00000158715          down    down
# 5   ENSG00000089127            up      up
# 6   ENSG00000179348          down    down
# 7   ENSG00000131016          down    down
# 8   ENSG00000187608            up      up
# 9   ENSG00000167483          down    down
# 10  ENSG00000134321            up      up
# 11  ENSG00000136573          down      up
# 12  ENSG00000171766          down      up
# 13  ENSG00000135114            up      up
# 14  ENSG00000185745            up      up
# 15  ENSG00000126709            up      up
# 16  ENSG00000132530            up      up
# 17  ENSG00000211892          down      up
# 18  ENSG00000105426          down    down
# 19  ENSG00000214711          down      up
# 20  ENSG00000119922            up      up
# ...

# %% [markdown]
# ### **Deseq2 protein codingDEGs intersection**

# %%
external_with_ori_protein_coding_degs = [
    "ENSG00000165949", "ENSG00000160932", "ENSG00000159958", "ENSG00000149534", "ENSG00000158715",
    "ENSG00000179348", "ENSG00000089127", "ENSG00000131016", "ENSG00000167483", "ENSG00000187608",
    "ENSG00000134321", "ENSG00000136573", "ENSG00000135114", "ENSG00000185745", "ENSG00000105426",
    "ENSG00000126709", "ENSG00000132530", "ENSG00000214711", "ENSG00000137094", "ENSG00000187912",
    "ENSG00000119922", "ENSG00000134326", "ENSG00000132185", "ENSG00000123095", "ENSG00000134668"
]

# %%
ori_up_protein_coding=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGS_UP(origin)(Deseq2)(protein coding genes).csv")
ori_down_protein_coding=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGS_DOWN(origin)(Deseq2)(protein coding genes).csv")

# %%
external_up_protein_coding=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGS_UP(external)(Deseq2)(protein coding genes).csv")
external_down_protein_coding=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGS_DOWN(external)(Deseq2)(protein coding genes).csv")

# %%
up_down_deg(external_with_ori_protein_coding_degs,external_up_protein_coding,external_down_protein_coding,ori_up_protein_coding,ori_down_protein_coding)
# Out:
#                 DEG external_DEGs My_DEGs
# 0   ENSG00000165949            up      up
# 1   ENSG00000160932            up      up
# 2   ENSG00000159958          down    down
# 3   ENSG00000149534          down    down
# 4   ENSG00000158715          down    down
# 5   ENSG00000179348          down    down
# 6   ENSG00000089127            up      up
# 7   ENSG00000131016          down    down
# 8   ENSG00000167483          down    down
# 9   ENSG00000187608            up      up
# 10  ENSG00000134321            up      up
# 11  ENSG00000136573          down      up
# 12  ENSG00000135114            up      up
# 13  ENSG00000185745            up      up
# 14  ENSG00000105426          down    down
# 15  ENSG00000126709            up      up
# 16  ENSG00000132530            up      up
# 17  ENSG00000214711          down      up
# 18  ENSG00000137094          down    down
# 19  ENSG00000187912          down    down
# 20  ENSG00000119922            up      up
# ...

# %%
external_with_ori_type_IFN_protein_coding_DEGs = [
    "ENSG00000131016", "ENSG00000160932",  "ENSG00000126709",
    "ENSG00000132530", "ENSG00000187608", "ENSG00000134326", "ENSG00000123095",
    "ENSG00000135114", "ENSG00000132185", "ENSG00000159958", "ENSG00000165949",
    "ENSG00000089127", "ENSG00000105426", "ENSG00000119922",
    "ENSG00000185745", "ENSG00000134321"
]

# %%
up_down_deg(external_with_ori_type_IFN_protein_coding_DEGs,external_up_protein_coding,external_down_protein_coding,ori_up_protein_coding,ori_down_protein_coding)
# Out:
#                 DEG external_DEGs My_DEGs
# 0   ENSG00000131016          down    down
# 1   ENSG00000160932            up      up
# 2   ENSG00000126709            up      up
# 3   ENSG00000132530            up      up
# 4   ENSG00000187608            up      up
# 5   ENSG00000134326            up      up
# 6   ENSG00000123095          down    down
# 7   ENSG00000135114            up      up
# 8   ENSG00000132185          down      up
# 9   ENSG00000159958          down    down
# 10  ENSG00000165949            up      up
# 11  ENSG00000089127            up      up
# 12  ENSG00000105426          down    down
# 13  ENSG00000119922            up      up
# 14  ENSG00000185745            up      up
# 15  ENSG00000134321            up      up

# %%
external_with_ori_HALLMARK_IFN_protein_coding_DEGs=[
    "ENSG00000160932",
    "ENSG00000187608",
    "ENSG00000134326",
    "ENSG00000135114",
    "ENSG00000165949",
    "ENSG00000089127",
    "ENSG00000119922",
    "ENSG00000134321"
]

# %%
up_down_deg(external_with_ori_HALLMARK_IFN_protein_coding_DEGs,external_up_protein_coding,external_down_protein_coding,ori_up_protein_coding,ori_down_protein_coding)
# Out:
#                DEG external_DEGs My_DEGs
# 0  ENSG00000160932            up      up
# 1  ENSG00000187608            up      up
# 2  ENSG00000134326            up      up
# 3  ENSG00000135114            up      up
# 4  ENSG00000165949            up      up
# 5  ENSG00000089127            up      up
# 6  ENSG00000119922            up      up
# 7  ENSG00000134321            up      up

# %% [markdown]
# ### **edgeR DEGs intersection**

# %%
external_with_ori_degs = [
    "ENSG00000160932", "ENSG00000187608", "ENSG00000089127", "ENSG00000134321",
    "ENSG00000126709", "ENSG00000135114", "ENSG00000159958", "ENSG00000134326",
]

# %%
external_up=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGs_UP(external)(edgeR).csv")
external_down=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGs_DOWN(external)(edgeR).csv")

# %%
ori_up=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGs_UP(edgeR).csv")
ori_down=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGs_DOWN(edgeR).csv")

# %%
up_down_deg(external_with_ori_degs,external_up,external_down,ori_up,ori_down)
# Out:
#                DEG external_DEGs My_DEGs
# 0  ENSG00000160932            up      up
# 1  ENSG00000187608            up      up
# 2  ENSG00000089127            up      up
# 3  ENSG00000134321            up      up
# 4  ENSG00000126709            up      up
# 5  ENSG00000135114            up      up
# 6  ENSG00000159958          down    down
# 7  ENSG00000134326            up      up

# %% [markdown]
# ### **edgeR protein codingDEGs intersection**

# %%
external_with_ori_protein_coding_degs = [
    "ENSG00000160932",
    "ENSG00000187608",
    "ENSG00000134321",
    "ENSG00000126709",
    "ENSG00000159958",
    "ENSG00000135114",
    "ENSG00000131016",
    "ENSG00000134326",
    "ENSG00000167483",
]

# %%
ori_up_protein_coding=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGs_UP(edgeR)(protein coding genes).csv")
ori_down_protein_coding=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGs_DOWN(edgeR)(protein coding genes).csv")

# %%
external_up_protein_coding=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGs_UP(external)(edgeR)(protein coding genes).csv")
external_down_protein_coding=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGs_DOWN(external)(edgeR)(protein coding genes).csv")

# %%
up_down_deg(external_with_ori_protein_coding_degs,external_up_protein_coding,external_down_protein_coding,ori_up_protein_coding,ori_down_protein_coding)
# Out:
#                DEG external_DEGs My_DEGs
# 0  ENSG00000160932            up      up
# 1  ENSG00000187608            up      up
# 2  ENSG00000134321            up      up
# 3  ENSG00000126709            up      up
# 4  ENSG00000159958          down    down
# 5  ENSG00000135114            up      up
# 6  ENSG00000131016          down    down
# 7  ENSG00000134326            up      up
# 8  ENSG00000167483          down    down

# %%
external_with_ori_type_IFN_protein_coding_DEGs  = [
    "ENSG00000126709",
    "ENSG00000131016",
    "ENSG00000160932",
    "ENSG00000187608",
    "ENSG00000134326",
    "ENSG00000135114",
    "ENSG00000159958",
    "ENSG00000134321",
]

# %%
up_down_deg(external_with_ori_type_IFN_protein_coding_DEGs,external_up_protein_coding,external_down_protein_coding,ori_up_protein_coding,ori_down_protein_coding)
# Out:
#                DEG external_DEGs My_DEGs
# 0  ENSG00000126709            up      up
# 1  ENSG00000131016          down    down
# 2  ENSG00000160932            up      up
# 3  ENSG00000187608            up      up
# 4  ENSG00000134326            up      up
# 5  ENSG00000135114            up      up
# 6  ENSG00000159958          down    down
# 7  ENSG00000134321            up      up

# %%
external_with_ori_HALLMARK_IFN_protein_coding_DEGs = [
    "ENSG00000160932",
    "ENSG00000187608",
    "ENSG00000134326",
    "ENSG00000135114",
    "ENSG00000134321",
]

# %%
up_down_deg(external_with_ori_HALLMARK_IFN_protein_coding_DEGs,external_up_protein_coding,external_down_protein_coding,ori_up_protein_coding,ori_down_protein_coding)
# Out:
#                DEG external_DEGs My_DEGs
# 0  ENSG00000160932            up      up
# 1  ENSG00000187608            up      up
# 2  ENSG00000134326            up      up
# 3  ENSG00000135114            up      up
# 4  ENSG00000134321            up      up

# %%
type_I_IFN_3DEGanalysis= [
    "ENSG00000126709",
    "ENSG00000131016",
    "ENSG00000160932",
    "ENSG00000187608",
    "ENSG00000134326",
    "ENSG00000135114",
    "ENSG00000159958",
]

# %%
up_down_deg(type_I_IFN_3DEGanalysis,external_up_protein_coding,external_down_protein_coding,ori_up_protein_coding,ori_down_protein_coding)
# Out:
#                DEG external_DEGs My_DEGs
# 0  ENSG00000126709            up      up
# 1  ENSG00000131016          down    down
# 2  ENSG00000160932            up      up
# 3  ENSG00000187608            up      up
# 4  ENSG00000134326            up      up
# 5  ENSG00000135114            up      up
# 6  ENSG00000159958          down    down

# %%
hallmark_type_I_IFN_3DEGanalysis = [
    "ENSG00000160932",
    "ENSG00000187608",
    "ENSG00000134326",
    "ENSG00000135114",
    "ENSG00000134321",
]

# %%
up_down_deg(hallmark_type_I_IFN_3DEGanalysis,external_up_protein_coding,external_down_protein_coding,ori_up_protein_coding,ori_down_protein_coding)
# Out:
#                DEG external_DEGs My_DEGs
# 0  ENSG00000160932            up      up
# 1  ENSG00000187608            up      up
# 2  ENSG00000134326            up      up
# 3  ENSG00000135114            up      up
# 4  ENSG00000134321            up      up

# %%
my_external_protein_coding_DEGs = [
    "ENSG00000187608",
    "ENSG00000126709",
    "ENSG00000134326",
    "ENSG00000131016",
    "ENSG00000136573",
    "ENSG00000160932",
    "ENSG00000135114",
    "ENSG00000167483",
    "ENSG00000159958",
]

# %%
ori_up_protein_coding=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGS_UP(my data)(Deseq2).csv")
ori_down_protein_coding=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGS_DOWN(my data)(Deseq2).csv")

# %%
external_up_protein_coding=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGS_UP(external data)(Deseq2).csv")
external_down_protein_coding=pd.read_csv("./RNA_DATA/NMOSD_RNA_DEGS_DOWN(external data)(Deseq2).csv")

# %%
up_down_deg(my_external_protein_coding_DEGs,external_up_protein_coding,external_down_protein_coding,ori_up_protein_coding,ori_down_protein_coding)
# Out:
#                DEG external_DEGs My_DEGs
# 0  ENSG00000187608            up      up
# 1  ENSG00000126709            up      up
# 2  ENSG00000134326            up      up
# 3  ENSG00000131016          down    down
# 4  ENSG00000136573          down      up
# 5  ENSG00000160932            up      up
# 6  ENSG00000135114            up      up
# 7  ENSG00000167483          down    down
# 8  ENSG00000159958          down    down

# %%
my_external_type_I_IFN_DEGs = [
    "ENSG00000187608",
    "ENSG00000134326"
]

# %%
up_down_deg(my_external_type_I_IFN_DEGs,external_up_protein_coding,external_down_protein_coding,ori_up_protein_coding,ori_down_protein_coding)
# Out:
#                DEG external_DEGs My_DEGs
# 0  ENSG00000187608            up      up
# 1  ENSG00000134326            up      up

# %%
a
